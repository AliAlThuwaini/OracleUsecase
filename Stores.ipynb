# %%
import os
os.chdir(r'G:\Ext_Disk_SharedFolder\Career\Oracle\ADW Challenge - Candidate Pack')
os.getcwd()
import pandas as pd
Stores = pd.read_excel('PCW15 D Stores.xlsx')

# %%
Stores.head()
# Out:
#    Store Id                       Store           Buyer   Store Type  \
# 0         1      Long Beach Electronics     Nass Torres  Electronics
# 1         2       San Diego Electronics  Sascha Johnson  Electronics
# 2         3  San Francisico Electronics      Kim Rogers  Electronics
# 3         4        Boston Tech Supplies    Kei Thompson    Discounts
# 4         5         Cambridge Discounts    Gabby Taylor    Discounts
#
#                  Street State            City    Zip
# 0     250 N Pacific Ave    CA      Long Beach  90802
# 1          440 Beech St    CA       San Diego  92101
# 2  3360 Cesar Chavez St    CA  San Francisico  94110
# 3   104-198 Merrimac St    MA          Boston   2114
# 4          6 Hillard St    MA       Cambridge   2138

# %%
Stores.shape
# Out:
# (12, 8)

# %%
Stores
# Out:
#     Store Id                       Store           Buyer   Store Type  \
# 0          1      Long Beach Electronics     Nass Torres  Electronics
# 1          2       San Diego Electronics  Sascha Johnson  Electronics
# 2          3  San Francisico Electronics      Kim Rogers  Electronics
# 3          4        Boston Tech Supplies    Kei Thompson    Discounts
# 4          5         Cambridge Discounts    Gabby Taylor    Discounts
# 5          6             Lowell Computer        Mo Myers     Computer
# 6          7   Jersey City Tech Supplies   Fran Sullivan    Discounts
# 7          8          Newark Electronics      Izzi Jones  Electronics
# 8          9    Patterson Communications       Nik Reyes     Computer
# 9         10      Buffalo Communications     Izzi Taylor     Computer
# 10        11         Manhattan Discounts   Chris Martino    Discounts
# 11        12         Rochester Discounts    Fran Frumine    Discounts
#
#                              Street State            City    Zip
# 0                 250 N Pacific Ave    CA      Long Beach  90802
# 1                      440 Beech St    CA       San Diego  92101
# 2              3360 Cesar Chavez St    CA  San Francisico  94110
# 3               104-198 Merrimac St    MA          Boston   2114
# 4                      6 Hillard St    MA       Cambridge   2138
# 5                  77 Chelmsford St    MA          Lowell   1851
# 6   114-122 Christopher Columbus Dr    NJ     Jersey City   7302
# 7                 113-139 Warren St    NJ          Newark   7103
# 8                    56 Hamilton St    NJ       Patterson   7505
# 9                  456-464 Pearl St    NY         Buffalo  14202
# 10                      1 W 47th St    NY       Manhattan  10036
# 11                   77 Franklin St    NY       Rochester  14604
