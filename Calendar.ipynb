# %%
import os
os.chdir(r'G:\Ext_Disk_SharedFolder\Career\Oracle\ADW Challenge - Candidate Pack')
os.getcwd()
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
Calendar = pd.read_excel('PCW15 D Calendar.xlsx',  parse_dates=True)

# %%
Calendar.head()
# Out:
#     Day Date D Nm  Day in Month  Day in Year Week End Mth Nm  Mth# Mth# Nm  \
# 0 2012-01-01  Sun             1            1    W-End    Jan     1  01 Jan
# 1 2012-01-02  Mon             2            2  Wrk-Day    Jan     1  01 Jan
# 2 2012-01-03  Tue             3            3  Wrk-Day    Jan     1  01 Jan
# 3 2012-01-04  Wed             4            4  Wrk-Day    Jan     1  01 Jan
# 4 2012-01-05  Thu             5            5  Wrk-Day    Jan     1  01 Jan
#
#   Qtr  Year Per Y Qtr Per Y Mth#  Fin Mth# Fin Qtr Fin Year Per Fin Qtr  \
# 0  Q1  2012   2012 Q1    2012 01         6    F Q2  F  2012  F  2012 Q2
# 1  Q1  2012   2012 Q1    2012 01         6    F Q2  F  2012  F  2012 Q2
# 2  Q1  2012   2012 Q1    2012 01         6    F Q2  F  2012  F  2012 Q2
# 3  Q1  2012   2012 Q1    2012 01         6    F Q2  F  2012  F  2012 Q2
# 4  Q1  2012   2012 Q1    2012 01         6    F Q2  F  2012  F  2012 Q2
#
#   Per Fin Mth# Fin Mth# Nm
# 0   F  2012 06      06 Jan
# 1   F  2012 06      06 Jan
# 2   F  2012 06      06 Jan
# 3   F  2012 06      06 Jan
# 4   F  2012 06      06 Jan

# %%
Calendar.columns
# Out:
# Index(['Day Date', 'D Nm', 'Day in Month', 'Day in Year', 'Week End', 'Mth Nm',
#        'Mth#', 'Mth# Nm', 'Qtr', 'Year', 'Per Y Qtr', 'Per Y Mth#', 'Fin Mth#',
#        'Fin Qtr', 'Fin Year', 'Per Fin Qtr', 'Per Fin Mth#', 'Fin Mth# Nm'],
#       dtype='object')
